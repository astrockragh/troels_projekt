# %%
import os, sys, uproot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import HomeMade as hm
from importlib import reload  
hm=reload(hm)
from iminuit import Minuit
from xgboost import XGBClassifier
import shap
import dill
from AppStatFunctions import Chi2Regression,UnbinnedLH, BinnedLH, add_text_to_ax, nice_string_output
from sklearn.preprocessing import RobustScaler
from hep_ml.reweight import GBReweighter
# Out:
# The sklearn.neighbors.unsupervised module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
# The sklearn.tree.tree module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.tree. Anything that cannot be imported from sklearn.tree is now part of the private API.

# %%
Nmax=2.4e6
uncorrelated=['v0_chi2', 'v0_px1', 'v0_phi1', 'v0_py1', 'v0_py', 'v0_py2', 'v0_phi2', 'v0_px2', 'v0_px', 'cosTheta', 'a0xy', 'a0', 'v0_y', 'v0_x', 'v0_rxyErr', 'v0_rxy','v0_z', 'pv0_z', 'pv0_y', 'ntrk_pv0', 'pv0_x']
ml1=['v0_chi2', 'v0_px1', 'v0_phi1', 'v0_py1', 'v0_py', 'v0_py2', 'v0_phi2', 'v0_px2', 'v0_px']
ml2=['cosTheta', 'a0xy', 'a0', 'v0_y', 'v0_x', 'v0_rxyErr', 'v0_rxy','v0_z', 'pv0_z', 'pv0_y', 'ntrk_pv0', 'pv0_x']
features=['v0_ks_mass','v0_chi2', 'v0_px1', 'v0_phi1', 'v0_py1', 'v0_py', 'v0_py2', 'v0_phi2', 'v0_px2', 'v0_px', 'cosTheta', 'a0xy', 'a0', 'v0_y', 'v0_x', 'v0_rxyErr', 'v0_rxy','v0_z', 'pv0_z', 'pv0_y', 'ntrk_pv0', 'pv0_x']
ML1=['v0_ks_mass','v0_chi2', 'v0_px1', 'v0_phi1', 'v0_py1', 'v0_py', 'v0_py2', 'v0_phi2', 'v0_px2', 'v0_px']
ML2=['v0_ks_mass','cosTheta', 'a0xy', 'a0', 'v0_y', 'v0_x', 'v0_rxyErr', 'v0_rxy','v0_z', 'pv0_z', 'pv0_y', 'ntrk_pv0', 'pv0_x']
featureml1=['v0_ks_mass','v0_chi2', 'v0_px1', 'v0_py1', 'v0_py', 'v0_py2', 'v0_px2', 'v0_px']
ml1draw=np.hstack((['v0_ks_mass'], ml1))
featureml2=['v0_ks_mass','cosTheta', 'a0', 'v0_y', 'v0_x', 'v0_rxyErr', 'v0_rxy','v0_z', 'ntrk_pv0']
ml2draw=np.hstack((['v0_ks_mass'], ml2))

# %%
N = Nmax*10
if N>Nmax:
#     N=Nmax
    print('Maxed out')

all_features = np.hstack((['v0_ks_mass'], uncorrelated))

path = "../../data/data15_13TeV.00267358.physics_MinBias.30062015_v0_per_0.root"
file = uproot.open(path)
data = file['tree'].pandas.df(all_features, entrystop = N)

path = "../../data/mc15_13TeV.361203.Pythia8_A2_MSTW2008LO_ND_minbias.30062015_v0_per_0.root"
file = uproot.open(path)
mc = file['tree'].pandas.df(np.hstack((all_features ,['trueKs'])), entrystop = N)
print(len(mc))
data = data.loc[(data.v0_ks_mass > 400) & (data.v0_ks_mass < 600)]

mc = mc.loc[(mc.v0_ks_mass > 400) & (mc.v0_ks_mass < 600)]
train_data = data.sample(frac=0.7)
test_data = data[~data.index.isin(train_data.index)]

mc = mc.loc[(mc.v0_ks_mass > 400) & (mc.v0_ks_mass < 600)]
train_mc = mc.sample(frac=0.7)
test_mc = mc[~mc.index.isin(train_mc.index)]
# Out:
# Maxed out
# 9254570

# %%
from scipy.optimize import curve_fit
from scipy.stats import norm, chi2

def fit_mass_double(xs, vals, errs, ax = None, guesses_bkgr = [0, 0, -10, 2000], guesses_sig = [498, 6, 17000], sigratio=2, depth=50, plot=True):
    """double gauss fit with mu_1=mu_2, with polynomial backgground fit: Give bincenter, vals, sig, a figure to plot, otherwise 
    it plots itself, guesses for both gaussian and background. Update might follow with updated estimation of guesses, but for
    the time being we use optimize.curvefit to give guesses for minuit
    
    Returns fig, ax, the full Minuit object, background amount and signal amount:
    """
    mask=vals>0
    xs, vals, errs=xs[mask], vals[mask], errs[mask]
    #look into automatizing the guesses
    mu, sigma, N = guesses_sig
    #Make a 5 sigma cut so only background is here
    bkgr_mask = (xs < mu-4*sigma) | (xs > mu+4*sigma)

    guesses_bkgr[-1] = (vals[np.argmin(xs-mu)]+vals[0]+vals[-1])/4
    if not ax and plot:
        fig, ax = plt.subplots(figsize = (16, 10), ncols = 2)
        ax_sig = ax[1]
        ax_all = ax[0]
        ax_all.plot(xs, vals, 'r.')
        ax_all.errorbar(xs, vals, errs, color = 'k', elinewidth = 1, capsize = 2, ls = 'none')

    def background_fit(x, a, b, c, d):
        return a * (x-mu) ** 3 + b * (x-mu) ** 2 + c * (x-mu) + d
    
    # The signal fit  Here gauss
    def sig1(x, mean, sig, size):
        return size*norm.pdf(x, mean, sig)
    
    def sig2(x, mean, sig, size):
        return size*norm.pdf(x, mean, sig)
    
    # The full fit
    def full_fit(x, mean, sig, size, f, sigmp, a, b, c, d):
        return background_fit(x, a, b, c, d) + f*sig1(x, mean, sig, size) + (1-f)*sig2(x, mean, sigmp*sig, size)
    
     # Background fit under here
    if sum(vals[bkgr_mask])==0:
        def background_fit(xs, a, b, c, d):
            return 0*xs
        b1, b2, b3, b4=0,0,0,0
    else:
        vals_b, cov_b = curve_fit(background_fit, xs[bkgr_mask], vals[bkgr_mask], p0 = guesses_bkgr)
        b1, b2, b3, b4 = vals_b
        bkgr_chi2 = Chi2Regression(background_fit, xs[bkgr_mask], vals[bkgr_mask], errs[bkgr_mask])
        bkgr_min  = Minuit(bkgr_chi2, pedantic = False, a = b1, b = b2, c = b3, d = b4)
        bkgr_min.migrad()
        counter = 0
        bkgr_min
        while not bkgr_min.valid and counter<depth:
            bkgr_min.migrad()
            counter += 1
        if not bkgr_min.valid: print("No background valid minimum found!")

        #Save guesses 
        b1, b2, b3, b4 = bkgr_min.args
    N=(max(vals[~bkgr_mask])- background_fit(xs[np.argmax(xs[~bkgr_mask])], b1, b2, b3, b4))*30
    # Full fit
    full_chi2 = Chi2Regression(full_fit, xs, vals, errs)
    full_min  = Minuit(full_chi2, pedantic = False, a = b1, b = b2, c = b3, d = b4, \
                       mean = mu, sig = sigma, size = N, f = 0.5, sigmp = sigratio)

    full_min.migrad()
    counter = 0
    while not full_min.valid and counter<5*depth:
        full_min = Minuit(full_chi2, pedantic = False, a = b1, b = b2, c = b3, d = b4, \
        mean = mu, sig = sigma*np.random.uniform(0.8,1.2), size = N*np.random.uniform(0.8,1.2),\
        f = 0.5*np.random.uniform(0.8,1.2), sigmp = sigratio*np.random.uniform(0.8,1.2))
        full_min.migrad()
        counter += 1
    if not full_min.valid: print(f"No valid double gaussian minimum found after {counter} tries!")

    mean, sig, size, f, sigmp, b1, b2, b3, b4 = full_min.args

    sig_amount = np.sum(abs(f*sig1(xs, mean, sig, size)) + (1-f)*abs(sig2(xs, mean, sigmp*sig, size)))
    bkg_amount = np.sum(abs(background_fit(xs, b1, b2, b3, b4)))
    if plot:
        ax_all.plot(xs, full_fit(xs, *full_min.args), "k-", label = "full_fit")
        ax_all.plot(xs, background_fit(xs, b1, b2, b3, b4),'b--',  label = "background_fit")

        ax_all.legend(loc = "upper right")

        # Details:
        text = {'chi2': full_min.fval, \
                'pval': chi2.sf(full_min.fval, len(xs) - len(full_min.args)), \
                'mean': f"{full_min.values['mean']:.1f} +/- {full_min.errors['mean']:.1f}",\
                'N':    f"{full_min.values['size']:.1f} +/- {full_min.errors['size']:.1f}"}

        text_output = nice_string_output(text)
        add_text_to_ax(0.55, 0.925, text_output, ax_all)

        # Plot signal seperately
        ax_sig.fill_between(xs, f*sig1(xs, mean, sig, size) + (1-f)*sig2(xs, mean, sigmp*sig, size), color = 'red', alpha = 0.5, label = "sig fit")
        ax_sig.plot(xs, f*sig1(xs, mean, sig, size),ls = '--', color = 'blue', alpha = 0.5, label = "sig fit")
        ax_sig.plot(xs, (1-f)*sig2(xs, mean, sigmp*sig, size),ls = '--', color = 'green', alpha = 0.5, label = "sig fit")

        vals_sig = vals - background_fit(xs, b1, b2, b3, b4)

        ax_sig.plot(xs, vals_sig, 'r.')
        ax_sig.errorbar(xs, vals_sig, errs, color = 'k', elinewidth = 1, capsize = 2, ls = 'none')



        text_a = {'sig_tight': np.round(f*sig_amount), \
                  'sig_broad': np.round((1-f)*sig_amount), \
                  'bkgr': np.round(bkg_amount), \
                  'sig/bkgr': sig_amount / bkg_amount}

        text_output = nice_string_output(text_a, decimals = 2)
        add_text_to_ax(0.60, 0.90, text_output, ax_sig)

        fig.tight_layout()
        return fig, ax, full_min, sig_amount, bkg_amount
    return full_min, sig_amount, bkg_amount

# %%
y, x, _ = hm.hist(data.v0_ks_mass, bins=100, range=(400,600))
fig, ax, fit, signal, bkgr = fit_mass_double(x, y, np.sqrt(y), guesses_sig=[498.9, 6, 20000])

# %%
y, x, _ = hm.hist(train_data.v0_ks_mass,bins=100, range=(400,600))
fig, ax, M, sig, bkgr = fit_mass_double(x,y,np.sqrt(y), guesses_bkgr = [0, 0, -10, 2000], guesses_sig = [498, 6, 20000])
mean, sigma = M.values['mean'], M.values['sig']
signal = train_data.loc[(train_data.v0_ks_mass > mean - sigma) & (train_data.v0_ks_mass < mean + sigma)]
bkgr_l = train_data.loc[(train_data.v0_ks_mass > mean - 10*sigma) & (train_data.v0_ks_mass < mean - 5*sigma)]
bkgr_r = train_data.loc[(train_data.v0_ks_mass > mean + 5*sigma) & (train_data.v0_ks_mass < mean + 10*sigma)]
ax[0].vlines([mean-sigma,mean+sigma,mean-15*sigma,mean-10*sigma,mean+10*sigma,mean+15*sigma],min(y),max(y))

min_sample = min([len(signal),len(bkgr_l),len(bkgr_r)])
if min_sample != len(signal):print("WARNING! decrease background sample size or increase signal sample size")


train_data_cut = pd.concat([signal.sample(min_sample),
                   bkgr_l.sample(min_sample),
                   bkgr_r.sample(min_sample)])
train_data_cut['y'] = np.append(np.ones(min_sample),[np.zeros(min_sample),np.zeros(min_sample)])
mean, sigma
# Out:
# (498.1867699787358, 5.581672258259335)

# %%
import xgboost
model_XG=xgboost.XGBClassifier()
setattr(model_XG, 'verbosity', 1)
model_XG.fit(train_data_cut[train_data_cut.columns[2:-1]],y=train_data_cut.y)
# Out:
# XGBClassifier()

# %%
p_XGall = model_XG.predict_proba(test_data[test_data.columns[2:]])[:,0]

# %%
fig1, ax1=plt.subplots(nrows=1,ncols=3, figsize=(15,5))
hm.roc_curve_data(test_data.v0_ks_mass, p_XGall, Npoints = 100, bins = 100, range = (400, 600), ax_roc = ax1[0] , c=1,
                  ax_fits=ax1[1], ax_hist=ax1[2],verbose = True, plimit = 0.01)
fig1.tight_layout()
# Out:
# Completed fit with Chi2: 114.5, p-val: 0.049 and the total amount of signal 31170 +/- 403, background: 688094
# Completed fit with Chi2: 115.0, p-val: 0.045 and the total amount of signal 24238 +/- 442, background: 687834
# Completed fit with Chi2: 117.3, p-val: 0.033 and the total amount of signal 17632 +/- nan, background: 687247
# Completed fit with Chi2: 117.4, p-val: 0.033 and the total amount of signal 11727 +/- nan, background: 685960
# Completed fit with Chi2: 118.4, p-val: 0.028 and the total amount of signal 6668 +/- 2, background: 683827
# Completed fit with Chi2: 122.3, p-val: 0.016 and the total amount of signal 2416 +/- 99, background: 680886
# Completed fit with Chi2: 132.1, p-val: 0.003 and the total amount of signal 415 +/- 34, background: 675695
# Completed fit with Chi2: 144.2, p-val: 0.000 and the total amount of signal 2 +/- nan, background: 668915
# Completed fit with Chi2: 146.5, p-val: 0.000 and the total amount of signal 0 +/- 53, background: 661723
# Completed fit with Chi2: 154.0, p-val: 0.000 and the total amount of signal 0 +/- 2, background: 654531
# Completed fit with Chi2: 159.0, p-val: 0.000 and the total amount of signal 0 +/- 3, background: 647338
# Completed fit with Chi2: 160.3, p-val: 0.000 and the total amount of signal 0 +/- 261, background: 640145
# Completed fit with Chi2: 164.6, p-val: 0.000 and the total amount of signal 0 +/- 172, background: 632953
# Completed fit with Chi2: 172.5, p-val: 0.000 and the total amount of signal 0 +/- 310, background: 625760
# Completed fit with Chi2: 180.1, p-val: 0.000 and the total amount of signal 0 +/- 806, background: 618568
# Completed fit with Chi2: 179.8, p-val: 0.000 and the total amount of signal 0 +/- 128, background: 611375
# Completed fit with Chi2: 188.0, p-val: 0.000 and the total amount of signal 0 +/- 211, background: 604182
# Completed fit with Chi2: 194.7, p-val: 0.000 and the total amount of signal 0 +/- nan, background: 596990
# Completed fit with Chi2: 197.4, p-val: 0.000 and the total amount of signal 0 +/- 64, background: 589797
# Completed fit with Chi2: 203.7, p-val: 0.000 and the total amount of signal 0 +/- nan, background: 582604
# Completed fit with Chi2: 206.4, p-val: 0.000 and the total amount of signal 0 +/- 884, background: 575412
# Completed fit with Chi2: 209.6, p-val: 0.000 and the total amount of signal 0 +/- 50, background: 568219
# Completed fit with Chi2: 216.2, p-val: 0.000 and the total amount of signal 0 +/- 55, background: 561026
# Completed fit with Chi2: 221.6, p-val: 0.000 and the total amount of signal 0 +/- 744, background: 553834
# Completed fit with Chi2: 221.9, p-val: 0.000 and the total amount of signal 0 +/- 128, background: 546641
# No valid minimum found!
# Completed fit with Chi2: 220.8, p-val: 0.000 and the total amount of signal 0 +/- 19177, background: 539448
# Completed fit with Chi2: 223.4, p-val: 0.000 and the total amount of signal 0 +/- 63, background: 532256
# Completed fit with Chi2: 217.9, p-val: 0.000 and the total amount of signal 0 +/- 140, background: 525063
# Completed fit with Chi2: 217.7, p-val: 0.000 and the total amount of signal 0 +/- 0, background: 517871
# Completed fit with Chi2: 212.3, p-val: 0.000 and the total amount of signal 0 +/- 487, background: 510678
# Completed fit with Chi2: 216.8, p-val: 0.000 and the total amount of signal 0 +/- 59, background: 503485
# Completed fit with Chi2: 211.9, p-val: 0.000 and the total amount of signal 0 +/- 191, background: 496293
# Completed fit with Chi2: 208.5, p-val: 0.000 and the total amount of signal 0 +/- 45, background: 489100
# No valid minimum found!
# Completed fit with Chi2: 207.7, p-val: 0.000 and the total amount of signal 0 +/- 19366, background: 481907
# Completed fit with Chi2: 210.4, p-val: 0.000 and the total amount of signal 0 +/- 35, background: 474715
# Completed fit with Chi2: 212.3, p-val: 0.000 and the total amount of signal 0 +/- 51, background: 467522
# Completed fit with Chi2: 210.5, p-val: 0.000 and the total amount of signal 0 +/- 105, background: 460329
# Completed fit with Chi2: 214.4, p-val: 0.000 and the total amount of signal 0 +/- 19402, background: 453137
# Completed fit with Chi2: 212.5, p-val: 0.000 and the total amount of signal 0 +/- 51, background: 445944
# Completed fit with Chi2: 216.1, p-val: 0.000 and the total amount of signal 0 +/- 64, background: 438752
# Completed fit with Chi2: 211.2, p-val: 0.000 and the total amount of signal 0 +/- 100, background: 431559
# Completed fit with Chi2: 209.4, p-val: 0.000 and the total amount of signal 0 +/- 52, background: 424366
# Completed fit with Chi2: 213.3, p-val: 0.000 and the total amount of signal 0 +/- 30262, background: 417174
# No valid minimum found!
# Completed fit with Chi2: 210.2, p-val: 0.000 and the total amount of signal 0 +/- 19584, background: 409981
# Completed fit with Chi2: 213.2, p-val: 0.000 and the total amount of signal 0 +/- 42, background: 402788
# No valid minimum found!
# Completed fit with Chi2: 214.6, p-val: 0.000 and the total amount of signal 0 +/- 30976, background: 395596
# Completed fit with Chi2: 218.2, p-val: 0.000 and the total amount of signal 0 +/- 161, background: 388403
# Completed fit with Chi2: 225.2, p-val: 0.000 and the total amount of signal 0 +/- 4, background: 381210
# Completed fit with Chi2: 225.5, p-val: 0.000 and the total amount of signal 0 +/- 54, background: 374018
# Completed fit with Chi2: 223.5, p-val: 0.000 and the total amount of signal 0 +/- 75, background: 366825
# Completed fit with Chi2: 222.1, p-val: 0.000 and the total amount of signal 0 +/- 19, background: 359632
# No valid minimum found!
# Completed fit with Chi2: 226.9, p-val: 0.000 and the total amount of signal 0 +/- 19157, background: 352440
# Completed fit with Chi2: 221.3, p-val: 0.000 and the total amount of signal 0 +/- 113, background: 345247
# Completed fit with Chi2: 215.7, p-val: 0.000 and the total amount of signal 0 +/- 195, background: 338055
# Completed fit with Chi2: 218.5, p-val: 0.000 and the total amount of signal 0 +/- 3708, background: 330862
# Completed fit with Chi2: 217.3, p-val: 0.000 and the total amount of signal 0 +/- 1789, background: 323669
# Completed fit with Chi2: 213.3, p-val: 0.000 and the total amount of signal 0 +/- 84, background: 316477
# Completed fit with Chi2: 210.7, p-val: 0.000 and the total amount of signal 0 +/- 23, background: 309284
# Completed fit with Chi2: 220.4, p-val: 0.000 and the total amount of signal 0 +/- 12, background: 302091
# No valid minimum found!
# Completed fit with Chi2: 213.0, p-val: 0.000 and the total amount of signal 0 +/- 30578, background: 294899
# Completed fit with Chi2: 212.8, p-val: 0.000 and the total amount of signal 0 +/- 70, background: 287706
# Completed fit with Chi2: 195.0, p-val: 0.000 and the total amount of signal 0 +/- 95, background: 280513
# Completed fit with Chi2: 186.8, p-val: 0.000 and the total amount of signal 0 +/- 1343, background: 273321
# Completed fit with Chi2: 178.6, p-val: 0.000 and the total amount of signal 0 +/- nan, background: 266128
# Completed fit with Chi2: 174.2, p-val: 0.000 and the total amount of signal 0 +/- 31, background: 258936
# Completed fit with Chi2: 169.0, p-val: 0.000 and the total amount of signal 0 +/- 80, background: 251743
# Completed fit with Chi2: 166.3, p-val: 0.000 and the total amount of signal 0 +/- 123, background: 244550
# Completed fit with Chi2: 160.8, p-val: 0.000 and the total amount of signal 0 +/- 154, background: 237358
# Completed fit with Chi2: 160.6, p-val: 0.000 and the total amount of signal 0 +/- 5021, background: 230165
# No valid minimum found!
# Completed fit with Chi2: 148.8, p-val: 0.000 and the total amount of signal 0 +/- 19196, background: 222972
# Completed fit with Chi2: 149.0, p-val: 0.000 and the total amount of signal 0 +/- 35, background: 215780
# Completed fit with Chi2: 142.5, p-val: 0.000 and the total amount of signal 0 +/- 4749, background: 208587
# Completed fit with Chi2: 139.3, p-val: 0.001 and the total amount of signal 0 +/- 381, background: 201394
# Completed fit with Chi2: 137.8, p-val: 0.001 and the total amount of signal 0 +/- 238, background: 194202
# Completed fit with Chi2: 140.0, p-val: 0.001 and the total amount of signal 0 +/- 0, background: 187009
# Completed fit with Chi2: 138.9, p-val: 0.001 and the total amount of signal 0 +/- 0, background: 179816
# Completed fit with Chi2: 140.4, p-val: 0.001 and the total amount of signal 0 +/- 0, background: 172624
# Completed fit with Chi2: 134.1, p-val: 0.002 and the total amount of signal 0 +/- 33, background: 165431
# Completed fit with Chi2: 134.4, p-val: 0.002 and the total amount of signal 0 +/- 5, background: 158239
# Completed fit with Chi2: 139.1, p-val: 0.001 and the total amount of signal 0 +/- 13, background: 151046
# No valid minimum found!
# Completed fit with Chi2: 132.1, p-val: 0.003 and the total amount of signal 0 +/- 19189, background: 143853
# Completed fit with Chi2: 122.0, p-val: 0.017 and the total amount of signal 0 +/- 231, background: 136661
# No valid minimum found!
# Completed fit with Chi2: 120.6, p-val: 0.021 and the total amount of signal 0 +/- 19381, background: 129468
# No valid minimum found!
# Completed fit with Chi2: 118.5, p-val: 0.028 and the total amount of signal 0 +/- 21761, background: 122275
# Completed fit with Chi2: 128.5, p-val: 0.006 and the total amount of signal 0 +/- 134, background: 115083
# No valid minimum found!
# Completed fit with Chi2: 138.6, p-val: 0.001 and the total amount of signal 0 +/- 19162, background: 107890
# Completed fit with Chi2: 139.6, p-val: 0.001 and the total amount of signal 0 +/- 9, background: 100697
# Completed fit with Chi2: 140.5, p-val: 0.001 and the total amount of signal 0 +/- 5, background: 93505
# Completed fit with Chi2: 147.0, p-val: 0.000 and the total amount of signal 0 +/- 8, background: 86312
# Completed fit with Chi2: 159.4, p-val: 0.000 and the total amount of signal 0 +/- 19, background: 79120
# Completed fit with Chi2: 165.3, p-val: 0.000 and the total amount of signal 0 +/- 4, background: 71927
# Completed fit with Chi2: 157.2, p-val: 0.000 and the total amount of signal 0 +/- 4, background: 64734
# Completed fit with Chi2: 148.2, p-val: 0.000 and the total amount of signal 0 +/- 5, background: 57542
# Completed fit with Chi2: 169.9, p-val: 0.000 and the total amount of signal 0 +/- 5, background: 50349
# Completed fit with Chi2: 153.8, p-val: 0.000 and the total amount of signal 0 +/- 2, background: 43156
# Completed fit with Chi2: 151.2, p-val: 0.000 and the total amount of signal 0 +/- 2, background: 35964
# Completed fit with Chi2: 146.7, p-val: 0.000 and the total amount of signal 0 +/- 2, background: 28771
# Completed fit with Chi2: 184.4, p-val: 0.000 and the total amount of signal 0 +/- 1, background: 21578
# Completed fit with Chi2: 203.2, p-val: 0.000 and the total amount of signal 58 +/- 40, background: 14328
# No handles with labels found to put in legend.
# Completed fit with Chi2: 133.4, p-val: 0.003 and the total amount of signal 473 +/- 35, background: 6721
# (-0.00391393185556871,
#  array([     0,   7192,  14385,  21577,  28770,  35963,  43155,  50348,
#          57541,  64733,  71926,  79119,  86311,  93504, 100696, 107889,
#         115082, 122274, 129467, 136660, 143852, 151045, 158238, 165430,
#         172623, 179816, 187008, 194201, 201393, 208586, 215779, 222971,
#         230164, 237357, 244549, 251742, 258935, 266127, 273320, 280512,
#         287705, 294898, 302090, 309283, 316476, 323668, 330861, 338054,
#         345246, 352439, 359632, 366824, 374017, 381209, 388402, 395595,
#         402787, 409980, 417173, 424365, 431558, 438751, 445943, 453136,
#         460328, 467521, 474714, 481906, 489099, 496292, 503484, 510677,
#         517870, 525062, 532255, 539448, 546640, 553833, 561025, 568218,
#         575411, 582603, 589796, 596989, 604181, 611374, 618567, 625759,
#         632952, 640144, 647337, 654530, 661722, 668915, 676108, 683300,
#         690493, 697686, 704878, 712071]))

# %%
model_XG=xgboost.XGBClassifier()

setattr(model_XG, 'verbosity', 1)
model_XG.fit(train_data_cut[ml1],y=train_data_cut.y)
p_XG1 = model_XG.predict_proba(test_data[ml1])[:,0]
fig1, ax1=plt.subplots(nrows=1,ncols=3, figsize=(15,5))
hm.roc_curve_data(test_data.v0_ks_mass, p_XG1, Npoints = 100, bins = 100, range = (400, 600), ax_roc = ax1[0] , c=1,
                  ax_fits=ax1[1], ax_hist=ax1[2],verbose = True, plimit = 0.01)
fig1.tight_layout()
# Out:
# Completed fit with Chi2: 114.5, p-val: 0.049 and the total amount of signal 31170 +/- 403, background: 688094
# Completed fit with Chi2: 115.1, p-val: 0.045 and the total amount of signal 26430 +/- 327, background: 685643
# No valid minimum found!
# Completed fit with Chi2: 116.9, p-val: 0.035 and the total amount of signal 22590 +/- 23053, background: 682290
# Completed fit with Chi2: 116.8, p-val: 0.036 and the total amount of signal 19062 +/- 386, background: 678626
# Completed fit with Chi2: 116.7, p-val: 0.036 and the total amount of signal 15925 +/- 214, background: 674570
# Completed fit with Chi2: 121.1, p-val: 0.019 and the total amount of signal 13481 +/- 206, background: 669821
# Completed fit with Chi2: 121.5, p-val: 0.018 and the total amount of signal 11539 +/- 322, background: 664570
# Completed fit with Chi2: 124.8, p-val: 0.011 and the total amount of signal 10297 +/- 14, background: 658619
# Completed fit with Chi2: 122.6, p-val: 0.015 and the total amount of signal 9310 +/- 128, background: 652414
# Completed fit with Chi2: 125.9, p-val: 0.009 and the total amount of signal 8418 +/- 362, background: 646114
# Completed fit with Chi2: 126.4, p-val: 0.008 and the total amount of signal 7611 +/- 290, background: 639727
# Completed fit with Chi2: 124.4, p-val: 0.011 and the total amount of signal 6992 +/- 193, background: 633153
# Completed fit with Chi2: 126.3, p-val: 0.009 and the total amount of signal 6496 +/- 237, background: 626457
# Completed fit with Chi2: 126.8, p-val: 0.008 and the total amount of signal 5825 +/- 311, background: 619936
# Completed fit with Chi2: 128.6, p-val: 0.006 and the total amount of signal 5346 +/- 222, background: 613223
# Completed fit with Chi2: 130.6, p-val: 0.004 and the total amount of signal 4778 +/- 315, background: 606597
# Completed fit with Chi2: 131.3, p-val: 0.004 and the total amount of signal 4300 +/- 317, background: 599883
# Completed fit with Chi2: 133.1, p-val: 0.003 and the total amount of signal 3768 +/- 132, background: 593223
# Completed fit with Chi2: 136.5, p-val: 0.001 and the total amount of signal 3249 +/- 1, background: 586548
# Completed fit with Chi2: 139.5, p-val: 0.001 and the total amount of signal 2814 +/- 37, background: 579790
# Completed fit with Chi2: 149.2, p-val: 0.000 and the total amount of signal 2243 +/- 173, background: 573170
# Completed fit with Chi2: 154.3, p-val: 0.000 and the total amount of signal 1997 +/- 267, background: 566222
# Completed fit with Chi2: 158.7, p-val: 0.000 and the total amount of signal 1568 +/- 169, background: 559458
# Completed fit with Chi2: 166.8, p-val: 0.000 and the total amount of signal 1288 +/- 241, background: 552546
# Completed fit with Chi2: 173.1, p-val: 0.000 and the total amount of signal 1028 +/- 224, background: 545614
# Completed fit with Chi2: 186.3, p-val: 0.000 and the total amount of signal 790 +/- 473, background: 538659
# Completed fit with Chi2: 194.8, p-val: 0.000 and the total amount of signal 688 +/- 225, background: 531569
# Completed fit with Chi2: 207.4, p-val: 0.000 and the total amount of signal 497 +/- 26, background: 524566
# Completed fit with Chi2: 217.6, p-val: 0.000 and the total amount of signal 408 +/- 178, background: 517464
# Completed fit with Chi2: 226.2, p-val: 0.000 and the total amount of signal 315 +/- 0, background: 510364
# Completed fit with Chi2: 235.0, p-val: 0.000 and the total amount of signal 245 +/- 34, background: 503241
# Completed fit with Chi2: 244.4, p-val: 0.000 and the total amount of signal 199 +/- 1, background: 496095
# Completed fit with Chi2: 260.5, p-val: 0.000 and the total amount of signal 130 +/- 1, background: 488971
# Completed fit with Chi2: 269.2, p-val: 0.000 and the total amount of signal 70 +/- 113, background: 481837
# Completed fit with Chi2: 276.0, p-val: 0.000 and the total amount of signal 38 +/- 18742, background: 474677
# Completed fit with Chi2: 285.4, p-val: 0.000 and the total amount of signal 0 +/- 39, background: 467522
# Completed fit with Chi2: 294.1, p-val: 0.000 and the total amount of signal 0 +/- 25, background: 460329
# Completed fit with Chi2: 313.2, p-val: 0.000 and the total amount of signal 0 +/- 0, background: 453137
# Completed fit with Chi2: 312.5, p-val: 0.000 and the total amount of signal 0 +/- 36, background: 445944
# Completed fit with Chi2: 312.9, p-val: 0.000 and the total amount of signal 0 +/- 0, background: 438752
# Completed fit with Chi2: 312.7, p-val: 0.000 and the total amount of signal 0 +/- 0, background: 431559
# Completed fit with Chi2: 317.4, p-val: 0.000 and the total amount of signal 0 +/- 125, background: 424366
# Completed fit with Chi2: 323.3, p-val: 0.000 and the total amount of signal 0 +/- 119, background: 417174
# Completed fit with Chi2: 323.4, p-val: 0.000 and the total amount of signal 0 +/- 28, background: 409981
# Completed fit with Chi2: 328.7, p-val: 0.000 and the total amount of signal 0 +/- 147, background: 402788
# Completed fit with Chi2: 332.7, p-val: 0.000 and the total amount of signal 0 +/- 80, background: 395596
# Completed fit with Chi2: 321.5, p-val: 0.000 and the total amount of signal 0 +/- 20, background: 388403
# Completed fit with Chi2: 309.8, p-val: 0.000 and the total amount of signal 0 +/- 21, background: 381210
# Completed fit with Chi2: 303.6, p-val: 0.000 and the total amount of signal 0 +/- 45, background: 374018
# Completed fit with Chi2: 289.1, p-val: 0.000 and the total amount of signal 0 +/- 202, background: 366825
# No valid minimum found!
# Completed fit with Chi2: 287.0, p-val: 0.000 and the total amount of signal 0 +/- 19161, background: 359632
# Completed fit with Chi2: 299.7, p-val: 0.000 and the total amount of signal 0 +/- 18, background: 352440
# Completed fit with Chi2: 308.8, p-val: 0.000 and the total amount of signal 0 +/- 17, background: 345247
# Completed fit with Chi2: 318.8, p-val: 0.000 and the total amount of signal 0 +/- 18, background: 338055
# No valid minimum found!
# Completed fit with Chi2: 325.2, p-val: 0.000 and the total amount of signal 0 +/- 19161, background: 330862
# Completed fit with Chi2: 331.5, p-val: 0.000 and the total amount of signal 0 +/- 7, background: 323669
# Completed fit with Chi2: 332.0, p-val: 0.000 and the total amount of signal 0 +/- 62, background: 316477
# Completed fit with Chi2: 330.8, p-val: 0.000 and the total amount of signal 0 +/- 106, background: 309284
# Completed fit with Chi2: 331.4, p-val: 0.000 and the total amount of signal 0 +/- 16, background: 302091
# No valid minimum found!
# Completed fit with Chi2: 332.9, p-val: 0.000 and the total amount of signal 0 +/- 19171, background: 294899
# No valid minimum found!
# Completed fit with Chi2: 335.7, p-val: 0.000 and the total amount of signal 0 +/- 19155, background: 287706
# Completed fit with Chi2: 344.6, p-val: 0.000 and the total amount of signal 0 +/- 4490, background: 280513
# Completed fit with Chi2: 344.9, p-val: 0.000 and the total amount of signal 0 +/- 25, background: 273321
# Completed fit with Chi2: 359.3, p-val: 0.000 and the total amount of signal 0 +/- 128, background: 266128
# Completed fit with Chi2: 373.0, p-val: 0.000 and the total amount of signal 0 +/- 39, background: 258936
# Completed fit with Chi2: 381.0, p-val: 0.000 and the total amount of signal 0 +/- 14, background: 251743
# Completed fit with Chi2: 387.4, p-val: 0.000 and the total amount of signal 0 +/- 0, background: 244550
# Completed fit with Chi2: 402.9, p-val: 0.000 and the total amount of signal 0 +/- 15, background: 237358
# No valid minimum found!
# Completed fit with Chi2: 406.3, p-val: 0.000 and the total amount of signal 0 +/- 15968, background: 230165
# No valid minimum found!
# Completed fit with Chi2: 411.7, p-val: 0.000 and the total amount of signal 0 +/- 19224, background: 222972
# Completed fit with Chi2: 445.0, p-val: 0.000 and the total amount of signal 0 +/- 16, background: 215780
# Completed fit with Chi2: 437.8, p-val: 0.000 and the total amount of signal 0 +/- 13, background: 208587
# Completed fit with Chi2: 417.9, p-val: 0.000 and the total amount of signal 0 +/- 17, background: 201394
# Completed fit with Chi2: 404.4, p-val: 0.000 and the total amount of signal 0 +/- 11, background: 194202
# Completed fit with Chi2: 377.5, p-val: 0.000 and the total amount of signal 0 +/- 12, background: 187009
# Completed fit with Chi2: 358.7, p-val: 0.000 and the total amount of signal 0 +/- 11, background: 179816
# Completed fit with Chi2: 322.3, p-val: 0.000 and the total amount of signal 0 +/- 4650, background: 172624
# Completed fit with Chi2: 299.2, p-val: 0.000 and the total amount of signal 0 +/- 18, background: 165431
# Completed fit with Chi2: 287.6, p-val: 0.000 and the total amount of signal 0 +/- 12, background: 158239
# Completed fit with Chi2: 251.6, p-val: 0.000 and the total amount of signal 0 +/- 10, background: 151046
# Completed fit with Chi2: 236.1, p-val: 0.000 and the total amount of signal 0 +/- 38, background: 143853
# Completed fit with Chi2: 226.8, p-val: 0.000 and the total amount of signal 0 +/- 8, background: 136661
# Completed fit with Chi2: 209.6, p-val: 0.000 and the total amount of signal 0 +/- 8, background: 129468
# Completed fit with Chi2: 192.6, p-val: 0.000 and the total amount of signal 0 +/- 8, background: 122275
# Completed fit with Chi2: 172.7, p-val: 0.000 and the total amount of signal 0 +/- 8, background: 115083
# Completed fit with Chi2: 163.6, p-val: 0.000 and the total amount of signal 0 +/- 8, background: 107890
# Completed fit with Chi2: 151.0, p-val: 0.000 and the total amount of signal 0 +/- 7, background: 100697
# Completed fit with Chi2: 142.9, p-val: 0.000 and the total amount of signal 47 +/- 480, background: 93459
# Completed fit with Chi2: 138.1, p-val: 0.001 and the total amount of signal 0 +/- 31124, background: 86312
# Completed fit with Chi2: 131.5, p-val: 0.004 and the total amount of signal 0 +/- 5, background: 79120
# Completed fit with Chi2: 123.3, p-val: 0.014 and the total amount of signal 56 +/- 65, background: 71871
# Completed fit with Chi2: 123.1, p-val: 0.014 and the total amount of signal 50 +/- 31, background: 64684
# Completed fit with Chi2: 122.5, p-val: 0.015 and the total amount of signal 44 +/- 235, background: 57499
# Completed fit with Chi2: 123.2, p-val: 0.014 and the total amount of signal 57 +/- 40, background: 50293
# Completed fit with Chi2: 124.7, p-val: 0.011 and the total amount of signal 25 +/- 40, background: 43132
# Completed fit with Chi2: 132.3, p-val: 0.003 and the total amount of signal 21 +/- 23, background: 35944
# Completed fit with Chi2: 165.3, p-val: 0.000 and the total amount of signal 18 +/- 30, background: 28754
# Completed fit with Chi2: 225.6, p-val: 0.000 and the total amount of signal 0 +/- 17, background: 21578
# Completed fit with Chi2: 356.5, p-val: 0.000 and the total amount of signal 0 +/- 0, background: 14386
# No handles with labels found to put in legend.
# Completed fit with Chi2: 54.1, p-val: 0.166 and the total amount of signal 0 +/- 28339, background: 7193

# %%
model_XG=xgboost.XGBClassifier()

setattr(model_XG, 'verbosity', 1)
model_XG.fit(train_data_cut[ml2],y=train_data_cut.y)
p_XG2 = model_XG.predict_proba(test_data[ml2])[:,0]
fig1, ax1=plt.subplots(nrows=1,ncols=3, figsize=(15,5))
hm.roc_curve_data(test_data.v0_ks_mass, p_XG2, Npoints = 100, bins = 100, range = (400, 600), ax_roc = ax1[0] , c=1,
                  ax_fits=ax1[1], ax_hist=ax1[2],verbose = True, plimit = 0.01)
fig1.tight_layout()
# Out:
# Completed fit with Chi2: 114.5, p-val: 0.049 and the total amount of signal 31170 +/- 403, background: 688094
# Completed fit with Chi2: 115.4, p-val: 0.043 and the total amount of signal 24060 +/- nan, background: 688013
# Completed fit with Chi2: 115.8, p-val: 0.041 and the total amount of signal 17647 +/- 409, background: 687232
# Completed fit with Chi2: 117.3, p-val: 0.033 and the total amount of signal 11868 +/- 271, background: 685820
# Completed fit with Chi2: 118.9, p-val: 0.027 and the total amount of signal 6854 +/- 385, background: 683640
# Completed fit with Chi2: 124.9, p-val: 0.011 and the total amount of signal 2299 +/- 0, background: 681003
# Completed fit with Chi2: 131.0, p-val: 0.004 and the total amount of signal 430 +/- 188, background: 675680
# Completed fit with Chi2: 145.4, p-val: 0.000 and the total amount of signal 31 +/- 15, background: 668885
# Completed fit with Chi2: 152.0, p-val: 0.000 and the total amount of signal 2 +/- 7, background: 661721
# Completed fit with Chi2: 159.2, p-val: 0.000 and the total amount of signal 0 +/- 0, background: 654531
# Completed fit with Chi2: 160.4, p-val: 0.000 and the total amount of signal 0 +/- 35, background: 647338
# Completed fit with Chi2: 157.4, p-val: 0.000 and the total amount of signal 0 +/- 2, background: 640145
# Completed fit with Chi2: 160.2, p-val: 0.000 and the total amount of signal 0 +/- 2607, background: 632953
# Completed fit with Chi2: 164.7, p-val: 0.000 and the total amount of signal 0 +/- 67, background: 625760
# Completed fit with Chi2: 167.5, p-val: 0.000 and the total amount of signal 0 +/- 59, background: 618568
# Completed fit with Chi2: 168.9, p-val: 0.000 and the total amount of signal 0 +/- 202, background: 611375
# No valid minimum found!
# Completed fit with Chi2: 171.9, p-val: 0.000 and the total amount of signal 0 +/- 15597, background: 604182
# Completed fit with Chi2: 171.5, p-val: 0.000 and the total amount of signal 0 +/- 222, background: 596990
# Completed fit with Chi2: 169.6, p-val: 0.000 and the total amount of signal 0 +/- 0, background: 589797
# Completed fit with Chi2: 165.6, p-val: 0.000 and the total amount of signal 0 +/- 49, background: 582604
# Completed fit with Chi2: 168.4, p-val: 0.000 and the total amount of signal 0 +/- 211, background: 575412
# Completed fit with Chi2: 173.4, p-val: 0.000 and the total amount of signal 0 +/- 141, background: 568219
# Completed fit with Chi2: 173.3, p-val: 0.000 and the total amount of signal 0 +/- 219, background: 561026
# Completed fit with Chi2: 170.0, p-val: 0.000 and the total amount of signal 0 +/- 80, background: 553834
# Completed fit with Chi2: 167.6, p-val: 0.000 and the total amount of signal 0 +/- 94, background: 546641
# Completed fit with Chi2: 167.5, p-val: 0.000 and the total amount of signal 0 +/- 831, background: 539448
# Completed fit with Chi2: 170.3, p-val: 0.000 and the total amount of signal 0 +/- nan, background: 532256
# Completed fit with Chi2: 169.3, p-val: 0.000 and the total amount of signal 0 +/- 142, background: 525063
# Completed fit with Chi2: 168.8, p-val: 0.000 and the total amount of signal 0 +/- 209, background: 517871
# Completed fit with Chi2: 165.1, p-val: 0.000 and the total amount of signal 0 +/- 43, background: 510678
# Completed fit with Chi2: 167.0, p-val: 0.000 and the total amount of signal 0 +/- 299, background: 503485
# Completed fit with Chi2: 167.4, p-val: 0.000 and the total amount of signal 0 +/- 54, background: 496293
# Completed fit with Chi2: 165.1, p-val: 0.000 and the total amount of signal 0 +/- 4789, background: 489100
# Completed fit with Chi2: 163.4, p-val: 0.000 and the total amount of signal 0 +/- 21, background: 481907
# Completed fit with Chi2: 163.0, p-val: 0.000 and the total amount of signal 0 +/- 87, background: 474715
# Completed fit with Chi2: 158.4, p-val: 0.000 and the total amount of signal 0 +/- 56, background: 467522
# Completed fit with Chi2: 157.2, p-val: 0.000 and the total amount of signal 0 +/- 6927, background: 460329
# Completed fit with Chi2: 148.2, p-val: 0.000 and the total amount of signal 0 +/- 63, background: 453137
# Completed fit with Chi2: 146.1, p-val: 0.000 and the total amount of signal 0 +/- 75, background: 445944
# Completed fit with Chi2: 151.8, p-val: 0.000 and the total amount of signal 0 +/- 153, background: 438752
# Completed fit with Chi2: 145.4, p-val: 0.000 and the total amount of signal 0 +/- 70, background: 431559
# Completed fit with Chi2: 143.9, p-val: 0.000 and the total amount of signal 0 +/- 1, background: 424366
# Completed fit with Chi2: 137.8, p-val: 0.001 and the total amount of signal 0 +/- 20987, background: 417174
# Completed fit with Chi2: 134.7, p-val: 0.002 and the total amount of signal 0 +/- 41, background: 409981
# Completed fit with Chi2: 132.3, p-val: 0.003 and the total amount of signal 0 +/- 1, background: 402788
# Completed fit with Chi2: 129.4, p-val: 0.005 and the total amount of signal 0 +/- 258, background: 395596
# Completed fit with Chi2: 128.8, p-val: 0.006 and the total amount of signal 0 +/- 19247, background: 388403
# Completed fit with Chi2: 123.2, p-val: 0.014 and the total amount of signal 0 +/- 1175, background: 381210
# Completed fit with Chi2: 118.2, p-val: 0.029 and the total amount of signal 0 +/- 205, background: 374018
# Completed fit with Chi2: 115.6, p-val: 0.042 and the total amount of signal 0 +/- 231, background: 366825
# Completed fit with Chi2: 109.7, p-val: 0.089 and the total amount of signal 0 +/- 152, background: 359632
# Completed fit with Chi2: 106.6, p-val: 0.126 and the total amount of signal 0 +/- 94, background: 352440
# Completed fit with Chi2: 103.9, p-val: 0.167 and the total amount of signal 0 +/- 548, background: 345247
# Completed fit with Chi2: 96.3, p-val: 0.332 and the total amount of signal 0 +/- 983, background: 338055
# Completed fit with Chi2: 98.3, p-val: 0.282 and the total amount of signal 0 +/- 0, background: 330862
# Completed fit with Chi2: 94.4, p-val: 0.382 and the total amount of signal 0 +/- nan, background: 323669
# Completed fit with Chi2: 97.0, p-val: 0.314 and the total amount of signal 0 +/- 102, background: 316477
# Completed fit with Chi2: 95.5, p-val: 0.352 and the total amount of signal 0 +/- 3, background: 309284
# Completed fit with Chi2: 96.3, p-val: 0.333 and the total amount of signal 0 +/- 0, background: 302091
# Completed fit with Chi2: 99.5, p-val: 0.254 and the total amount of signal 7 +/- 0, background: 294892
# Completed fit with Chi2: 103.8, p-val: 0.169 and the total amount of signal 0 +/- 0, background: 287706
# Completed fit with Chi2: 109.5, p-val: 0.091 and the total amount of signal 0 +/- 0, background: 280513
# Completed fit with Chi2: 116.3, p-val: 0.038 and the total amount of signal 0 +/- 0, background: 273321
# Completed fit with Chi2: 115.0, p-val: 0.045 and the total amount of signal 0 +/- 5241, background: 266128
# Completed fit with Chi2: 115.2, p-val: 0.044 and the total amount of signal 0 +/- 0, background: 258936
# Completed fit with Chi2: 106.4, p-val: 0.129 and the total amount of signal 0 +/- 2, background: 251743
# Completed fit with Chi2: 105.5, p-val: 0.141 and the total amount of signal 0 +/- 130, background: 244550
# Completed fit with Chi2: 104.7, p-val: 0.154 and the total amount of signal 0 +/- 33, background: 237358
# Completed fit with Chi2: 110.5, p-val: 0.081 and the total amount of signal 0 +/- 223, background: 230165
# Completed fit with Chi2: 114.3, p-val: 0.050 and the total amount of signal 0 +/- 1244, background: 222972
# Completed fit with Chi2: 110.3, p-val: 0.083 and the total amount of signal 0 +/- 103, background: 215780
# Completed fit with Chi2: 103.4, p-val: 0.176 and the total amount of signal 0 +/- nan, background: 208587
# Completed fit with Chi2: 106.4, p-val: 0.128 and the total amount of signal 0 +/- 138, background: 201394
# Completed fit with Chi2: 107.3, p-val: 0.117 and the total amount of signal 0 +/- 12, background: 194202
# Completed fit with Chi2: 98.7, p-val: 0.273 and the total amount of signal 0 +/- nan, background: 187009
# Completed fit with Chi2: 99.8, p-val: 0.248 and the total amount of signal 0 +/- 456, background: 179816
# Completed fit with Chi2: 102.6, p-val: 0.190 and the total amount of signal 9 +/- 2, background: 172615
# Completed fit with Chi2: 104.9, p-val: 0.151 and the total amount of signal 0 +/- 0, background: 165431
# No valid minimum found!
# Completed fit with Chi2: 103.2, p-val: 0.180 and the total amount of signal 22 +/- 18846, background: 158217
# Completed fit with Chi2: 103.0, p-val: 0.183 and the total amount of signal 27 +/- 94, background: 151020
# Completed fit with Chi2: 104.2, p-val: 0.162 and the total amount of signal 63 +/- 77, background: 143790
# Completed fit with Chi2: 108.0, p-val: 0.108 and the total amount of signal 58 +/- 12, background: 136603
# Completed fit with Chi2: 109.8, p-val: 0.088 and the total amount of signal 78 +/- 78, background: 129390
# Completed fit with Chi2: 111.8, p-val: 0.068 and the total amount of signal 86 +/- 13, background: 122189
# Completed fit with Chi2: 113.6, p-val: 0.054 and the total amount of signal 93 +/- 39, background: 114991
# Completed fit with Chi2: 111.7, p-val: 0.070 and the total amount of signal 88 +/- 60, background: 107803
# Completed fit with Chi2: 104.0, p-val: 0.165 and the total amount of signal 98 +/- 4, background: 100599
# Completed fit with Chi2: 107.4, p-val: 0.116 and the total amount of signal 71 +/- 66, background: 93435
# Completed fit with Chi2: 102.2, p-val: 0.198 and the total amount of signal 77 +/- 62, background: 86236
# Completed fit with Chi2: 98.0, p-val: 0.288 and the total amount of signal 58 +/- 48, background: 79063
# Completed fit with Chi2: 96.9, p-val: 0.318 and the total amount of signal 34 +/- 14, background: 71893
# Completed fit with Chi2: 98.6, p-val: 0.274 and the total amount of signal 19 +/- 0, background: 64716
# Completed fit with Chi2: 106.3, p-val: 0.130 and the total amount of signal 20 +/- 50, background: 57523
# Completed fit with Chi2: 121.9, p-val: 0.017 and the total amount of signal 91 +/- 2, background: 50259
# Completed fit with Chi2: 120.6, p-val: 0.021 and the total amount of signal 434 +/- 163, background: 42723
# Completed fit with Chi2: 116.2, p-val: 0.038 and the total amount of signal 948 +/- 326, background: 35017
# Completed fit with Chi2: 126.7, p-val: 0.008 and the total amount of signal 591 +/- 267, background: 28181
# Completed fit with Chi2: 170.1, p-val: 0.000 and the total amount of signal 68 +/- 39, background: 21510
# Completed fit with Chi2: 215.5, p-val: 0.000 and the total amount of signal 0 +/- 46, background: 14386
# No handles with labels found to put in legend.
# Completed fit with Chi2: 233.3, p-val: 0.000 and the total amount of signal 955 +/- 43, background: 6238
# (-0.005107038014821163,
#  array([     0,   7192,  14385,  21577,  28770,  35963,  43155,  50348,
#          57541,  64733,  71926,  79119,  86311,  93504, 100696, 107889,
#         115082, 122274, 129467, 136660, 143852, 151045, 158238, 165430,
#         172623, 179816, 187008, 194201, 201393, 208586, 215779, 222971,
#         230164, 237357, 244549, 251742, 258935, 266127, 273320, 280512,
#         287705, 294898, 302090, 309283, 316476, 323668, 330861, 338054,
#         345246, 352439, 359632, 366824, 374017, 381209, 388402, 395595,
#         402787, 409980, 417173, 424365, 431558, 438751, 445943, 453136,
#         460328, 467521, 474714, 481906, 489099, 496292, 503484, 510677,
#         517870, 525062, 532255, 539448, 546640, 553833, 561025, 568218,
#         575411, 582603, 589796, 596989, 604181, 611374, 618567, 625759,
#         632952, 640144, 647337, 654530, 661722, 668915, 676108, 683300,
#         690493, 697686, 704878, 712071]))

# %%
plt.hist(p_XG1, bins=100);
true1=p_XG1<0.2

# %%
plt.hist(test_data.v0_ks_mass[true1], bins=100);

# %%
from sklearn.metrics import roc_curve, roc_auc_score
fpr, tpr, thresholds = roc_curve(y_true=true1, y_score=p_XG2)

fig, ax = plt.subplots()
ax.plot(tpr,fpr)
ax.plot([0,1],[0,1],c='grey',linestyle='--')
ax.set_title(f'Crosscheck ML2/ML1, ROC curve, AUC: {np.round(1-roc_auc_score(y_true=true1,y_score=p_XG2),4)}')
# Out:
# Text(0.5, 1.0, 'Crosscheck ML2/ML1, ROC curve, AUC: 0.9007')

# %%
plt.hist(p_XG2, bins=100);
true2=p_XG2<0.25

# %%
plt.hist(test_data.v0_ks_mass[true2], bins=100);

# %%
from sklearn.metrics import roc_curve, roc_auc_score
fpr, tpr, thresholds = roc_curve(y_true=true2, y_score=p_XG1)

fig, ax = plt.subplots()
ax.plot(tpr,fpr)
ax.plot([0,1],[0,1],c='grey',linestyle='--')
ax.set_title(f'Crosscheck ML1/ML2, ROC curve, AUC: {np.round(1-roc_auc_score(y_true=true2,y_score=p_XG1),4)}')
# Out:
# Text(0.5, 1.0, 'Crosscheck ML1/ML2, ROC curve, AUC: 0.9464')

# %%
model_XG=xgboost.XGBClassifier()

setattr(model_XG, 'verbosity', 1)
model_XG.fit(test_mc[uncorrelated],y=test_mc.trueKs)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-48-d6d78fcf3e1e> in <module>
#       2
#       3 setattr(model_XG, 'verbosity', 1)
# ----> 4 model_XG.fit(test_mc[uncorrelated],y=test_mc.trueKs)
#
# ~\Anaconda3\lib\site-packages\xgboost\sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     724         else:
#     725             train_dmatrix = DMatrix(X, label=training_labels,
# --> 726                                     missing=self.missing, nthread=self.n_jobs)
#     727
#     728         self._Booster = train(xgb_options, train_dmatrix, self.get_num_boosting_rounds(),
#
# ~\Anaconda3\lib\site-packages\xgboost\core.py in __init__(self, data, label, missing, weight, silent, feature_names, feature_types, nthread)
#     378         data, feature_names, feature_types = _maybe_pandas_data(data,
#     379                                                                 feature_names,
# --> 380                                                                 feature_types)
#     381
#     382         data, feature_names, feature_types = _maybe_dt_data(data,
#
# ~\Anaconda3\lib\site-packages\xgboost\core.py in _maybe_pandas_data(data, feature_names, feature_types)
#     251         feature_types = [PANDAS_DTYPE_MAPPER[dtype.name] for dtype in data_dtypes]
#     252
# --> 253     data = data.values.astype('float')
#     254
#     255     return data, feature_names, feature_types
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in values(self)
#    5332         """
#    5333         self._consolidate_inplace()
# -> 5334         return self._mgr.as_array(transpose=self._AXIS_REVERSED)
#    5335
#    5336     @property
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in as_array(self, transpose, dtype, copy, na_value)
#     852                     arr = arr.astype(dtype, copy=False)
#     853         else:
# --> 854             arr = self._interleave(dtype=dtype, na_value=na_value)
#     855             # The underlying data was copied within _interleave
#     856             copy = False
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in _interleave(self, dtype, na_value)
#     881             dtype = "object"
#     882
# --> 883         result = np.empty(self.shape, dtype=dtype)
#     884
#     885         itemmask = np.zeros(self.shape[0])
#
# MemoryError: Unable to allocate 233. MiB for an array with shape (21, 1452168) and data type float64

# %%
pmc=model_XG.predict_proba(train_data[uncorrelated])
plt.hist(pmc, bins=100);
truemc=pmc<0.2

# %%
plt.hist(train_data.v0_ks_mass[truemc], bins=100);

# %%
fpr, tpr, thresholds = roc_curve(y_true=truemc, y_score=p_XGall)

fig, ax = plt.subplots()
ax.plot(tpr,fpr)
ax.plot([0,1],[0,1],c='grey',linestyle='--')
ax.set_title(f'Crosscheck 1+2 between data and MC, ROC curve, AUC: {np.round(1-roc_auc_score(y_true=truemc,y_score=p_XGall),4)}')
