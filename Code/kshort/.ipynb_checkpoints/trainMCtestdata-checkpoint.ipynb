# %%
import os, sys, uproot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import HomeMade as hm
import seaborn as sb
from iminuit import Minuit
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
import shap
import dill
from AppStatFunctions import Chi2Regression,UnbinnedLH, BinnedLH, add_text_to_ax, nice_string_output

# %%
Nmax=2.4e6
N = 5e5
if N>Nmax:
    N=Nmax
    print('Maxed out')

all_features = "v0_ks_mass v0_ks_massErr pv0_x pv0_y pv0_z a0xy a0 a0z cosTheta v0_chi2 \
v0_x v0_y v0_z v0_rxy v0_rxyErr v0_px v0_py v0_pz v0_pt v0_p \
v0_ptErr \
v0_px1 v0_py1 v0_pz1 v0_pt1 \
v0_p1 v0_px2 v0_py2 v0_pz2 v0_pt2 v0_p2 v0_phi1 v0_theta1 \
v0_qOverP1 v0_phi2 v0_theta2 v0_qOverP2 alpha calpha epsilon1 \
epsilon2 Alpha pL1 pL2 pT thetastar rapidity_ks ntrk_pv0 pseudorapidity".split(" ")

path = "../../data/data15_13TeV.00267358.physics_MinBias.30062015_v0_per_0.root"
file = uproot.open(path)
data = file['tree'].pandas.df(all_features, entrystop = N)

path = "../../data/mc15_13TeV.361203.Pythia8_A2_MSTW2008LO_ND_minbias.30062015_v0_per_0.root"
file = uproot.open(path)
mc = file['tree'].pandas.df(all_features + ['trueKs'], entrystop = N)

data = data.loc[(data.v0_ks_mass > 400) & (data.v0_ks_mass < 600)]
train_data = data.sample(frac=0.7)
test_data = data[~data.index.isin(train_data.index)]

mc = mc.loc[(mc.v0_ks_mass > 400) & (mc.v0_ks_mass < 600)]
train_mc = mc.sample(frac=0.7)
test_mc = mc[~mc.index.isin(train_mc.index)]

# %%
from scipy.optimize import curve_fit
from scipy.stats import norm, chi2

def fit_mass_double(xs, vals, errs, ax = None, guesses_bkgr = [0, 0, -10, 2000], guesses_sig = [498, 6, 17000], sigratio=2, depth=50, plot=True):
    """double gauss fit with mu_1=mu_2, with polynomial backgground fit: Give bincenter, vals, sig, a figure to plot, otherwise 
    it plots itself, guesses for both gaussian and background. Update might follow with updated estimation of guesses, but for
    the time being we use optimize.curvefit to give guesses for minuit
    
    Returns fig, ax, the full Minuit object, background amount and signal amount:
    """
    mask=vals>0
    xs, vals, errs=xs[mask], vals[mask], errs[mask]
    #look into automatizing the guesses
    mu, sigma, N = guesses_sig
    #Make a 5 sigma cut so only background is here
    bkgr_mask = (xs < mu-4*sigma) | (xs > mu+4*sigma)

    guesses_bkgr[-1] = (vals[np.argmin(xs-mu)]+vals[0]+vals[-1])/4
    if not ax and plot:
        fig, ax = plt.subplots(figsize = (16, 10), ncols = 2)
        ax_sig = ax[1]
        ax_all = ax[0]
        ax_all.plot(xs, vals, 'r.')
        ax_all.errorbar(xs, vals, errs, color = 'k', elinewidth = 1, capsize = 2, ls = 'none')

    def background_fit(x, a, b, c, d):
        return a * (x-mu) ** 3 + b * (x-mu) ** 2 + c * (x-mu) + d
    
    # The signal fit  Here gauss
    def sig1(x, mean, sig, size):
        return size*norm.pdf(x, mean, sig)
    
    def sig2(x, mean, sig, size):
        return size*norm.pdf(x, mean, sig)
    
    # The full fit
    def full_fit(x, mean, sig, size, f, sigmp, a, b, c, d):
        return background_fit(x, a, b, c, d) + f*sig1(x, mean, sig, size) + (1-f)*sig2(x, mean, sigmp*sig, size)
    
     # Background fit under here
    if sum(vals[bkgr_mask])==0:
        def background_fit(xs, a, b, c, d):
            return 0*xs
        b1, b2, b3, b4=0,0,0,0
    else:
        vals_b, cov_b = curve_fit(background_fit, xs[bkgr_mask], vals[bkgr_mask], p0 = guesses_bkgr)
        b1, b2, b3, b4 = vals_b
        bkgr_chi2 = Chi2Regression(background_fit, xs[bkgr_mask], vals[bkgr_mask], errs[bkgr_mask])
        bkgr_min  = Minuit(bkgr_chi2, pedantic = False, a = b1, b = b2, c = b3, d = b4)
        bkgr_min.migrad()
        counter = 0
        bkgr_min
        while not bkgr_min.valid and counter<depth:
            bkgr_min.migrad()
            counter += 1
        if not bkgr_min.valid: print("No background valid minimum found!")

        #Save guesses 
        b1, b2, b3, b4 = bkgr_min.args
    N=(max(vals[~bkgr_mask])- background_fit(xs[np.argmax(xs[~bkgr_mask])], b1, b2, b3, b4))*30
    # Full fit
    full_chi2 = Chi2Regression(full_fit, xs, vals, errs)
    full_min  = Minuit(full_chi2, pedantic = False, a = b1, b = b2, c = b3, d = b4, \
                       mean = mu, sig = sigma, size = N, f = 0.5, sigmp = sigratio)

    full_min.migrad()
    counter = 0
    while not full_min.valid and counter<5*depth:
        full_min = Minuit(full_chi2, pedantic = False, a = b1, b = b2, c = b3, d = b4, \
        mean = mu, sig = sigma*np.random.uniform(0.8,1.2), size = N*np.random.uniform(0.8,1.2),\
        f = 0.5*np.random.uniform(0.8,1.2), sigmp = sigratio*np.random.uniform(0.8,1.2))
        full_min.migrad()
        counter += 1
    if not full_min.valid: print(f"No valid double gaussian minimum found after {counter} tries!")

    mean, sig, size, f, sigmp, b1, b2, b3, b4 = full_min.args

    sig_amount = np.sum(abs(f*sig1(xs, mean, sig, size)) + (1-f)*abs(sig2(xs, mean, sigmp*sig, size)))
    bkg_amount = np.sum(abs(background_fit(xs, b1, b2, b3, b4)))
    if plot:
        ax_all.plot(xs, full_fit(xs, *full_min.args), "k-", label = "full_fit")
        ax_all.plot(xs, background_fit(xs, b1, b2, b3, b4),'b--',  label = "background_fit")

        ax_all.legend(loc = "upper right")

        # Details:
        text = {'chi2': full_min.fval, \
                'pval': chi2.sf(full_min.fval, len(xs) - len(full_min.args)), \
                'mean': f"{full_min.values['mean']:.1f} +/- {full_min.errors['mean']:.1f}",\
                'N':    f"{full_min.values['size']:.1f} +/- {full_min.errors['size']:.1f}"}

        text_output = nice_string_output(text)
        add_text_to_ax(0.55, 0.925, text_output, ax_all)

        # Plot signal seperately
        ax_sig.fill_between(xs, f*sig1(xs, mean, sig, size) + (1-f)*sig2(xs, mean, sigmp*sig, size), color = 'red', alpha = 0.5, label = "sig fit")
        ax_sig.plot(xs, f*sig1(xs, mean, sig, size),ls = '--', color = 'blue', alpha = 0.5, label = "sig fit")
        ax_sig.plot(xs, (1-f)*sig2(xs, mean, sigmp*sig, size),ls = '--', color = 'green', alpha = 0.5, label = "sig fit")

        vals_sig = vals - background_fit(xs, b1, b2, b3, b4)

        ax_sig.plot(xs, vals_sig, 'r.')
        ax_sig.errorbar(xs, vals_sig, errs, color = 'k', elinewidth = 1, capsize = 2, ls = 'none')



        text_a = {'sig_tight': np.round(f*sig_amount), \
                  'sig_broad': np.round((1-f)*sig_amount), \
                  'bkgr': np.round(bkg_amount), \
                  'sig/bkgr': sig_amount / bkg_amount}

        text_output = nice_string_output(text_a, decimals = 2)
        add_text_to_ax(0.60, 0.90, text_output, ax_sig)

        fig.tight_layout()
        return fig, ax, full_min, sig_amount, bkg_amount
    return full_min, sig_amount, bkg_amount

# %%
uncorrelated=np.array(['v0_chi2', 'v0_px1', 'v0_phi1', 'v0_py1', 'v0_py', 'v0_py2', 'v0_phi2', 'v0_px2', 'v0_px', 'cosTheta', 'a0xy', 'a0', 'v0_y', 'v0_x', 'v0_rxyErr', 'v0_z', 'pv0_z', 'pv0_y', 'ntrk_pv0', 'pv0_x'])

# %% [markdown]
# # Test without reweighting

# %%
XG_mc=XGBClassifier()
setattr(XG_mc, 'verbosity', 1)
XG_mc.fit(mc[uncorrelated],y=mc.trueKs)
# Out:
# XGBClassifier()

# %%
p_XG = XG_mc.predict_proba(train_data[uncorrelated])[:,1]

# %%
plt.hist(p_XG);

# %%
true=p_XG>0.7

# %%
train_data['y'] = true

# %%
model_XG=XGBClassifier()
setattr(model_XG, 'verbosity', 1)
model_XG.fit(train_data[uncorrelated],y=train_data.y);

# %%
pdat = model_XG.predict_proba(test_data[uncorrelated])[:,0]

# %%
fig, ax = plt.subplots()
ax.hist(pdat,bins=100);
ax.set_yscale('log')

fig, ax = plt.subplots()
ax.hist(test_data.loc[pdat>0.999].v0_ks_mass,bins=100);

# %%
fig1, ax1=plt.subplots(figsize=(10,8))
fig2, ax2=plt.subplots(figsize=(10,8))
hm.roc_curve_data(test_data.v0_ks_mass, pdat, Npoints = 100, bins = 100, range = (400, 600), ax_roc = ax1 ,\
               ax_fits = ax2, verbose = True, plimit = 0.01)
# Out:
# Completed fit with Chi2: 91.0, p-val: 0.479 and the total amount of signal 3004 +/- 161, background: 58655
# Completed fit with Chi2: 91.2, p-val: 0.476 and the total amount of signal 2454 +/- 147, background: 58589
# Completed fit with Chi2: 89.4, p-val: 0.528 and the total amount of signal 1927 +/- 98, background: 58500
# Completed fit with Chi2: 90.7, p-val: 0.490 and the total amount of signal 1393 +/- 132, background: 58417
# Completed fit with Chi2: 88.3, p-val: 0.559 and the total amount of signal 915 +/- 132, background: 58278
# Completed fit with Chi2: 89.0, p-val: 0.539 and the total amount of signal 488 +/- 125, background: 58090
# No valid minimum found!
# Completed fit with Chi2: 90.1, p-val: 0.508 and the total amount of signal 242 +/- 1557, background: 57719
# Completed fit with Chi2: 89.0, p-val: 0.540 and the total amount of signal 202 +/- 48, background: 57142
# Completed fit with Chi2: 87.5, p-val: 0.584 and the total amount of signal 201 +/- 57, background: 56527
# Completed fit with Chi2: 84.7, p-val: 0.666 and the total amount of signal 191 +/- 56, background: 55920
# Completed fit with Chi2: 87.6, p-val: 0.582 and the total amount of signal 187 +/- 56, background: 55308
# Completed fit with Chi2: 88.9, p-val: 0.543 and the total amount of signal 177 +/- 58, background: 54700
# Completed fit with Chi2: 86.8, p-val: 0.606 and the total amount of signal 174 +/- 41, background: 54087
# Completed fit with Chi2: 85.2, p-val: 0.652 and the total amount of signal 170 +/- 57, background: 53474
# Completed fit with Chi2: 85.5, p-val: 0.642 and the total amount of signal 165 +/- 58, background: 52863
# Completed fit with Chi2: 86.7, p-val: 0.607 and the total amount of signal 169 +/- 56, background: 52243
# Completed fit with Chi2: 89.7, p-val: 0.519 and the total amount of signal 173 +/- 38, background: 51621
# Completed fit with Chi2: 88.2, p-val: 0.563 and the total amount of signal 172 +/- 3, background: 51005
# Completed fit with Chi2: 86.3, p-val: 0.618 and the total amount of signal 179 +/- 1, background: 50383
# Completed fit with Chi2: 85.4, p-val: 0.646 and the total amount of signal 174 +/- 52, background: 49771
# Completed fit with Chi2: 88.9, p-val: 0.543 and the total amount of signal 176 +/- 53, background: 49152
# Completed fit with Chi2: 92.4, p-val: 0.438 and the total amount of signal 178 +/- 0, background: 48533
# Completed fit with Chi2: 93.6, p-val: 0.404 and the total amount of signal 171 +/- 0, background: 47924
# Completed fit with Chi2: 90.1, p-val: 0.506 and the total amount of signal 172 +/- 46, background: 47307
# Completed fit with Chi2: 87.4, p-val: 0.587 and the total amount of signal 157 +/- 2, background: 46705
# Completed fit with Chi2: 91.1, p-val: 0.477 and the total amount of signal 150 +/- 0, background: 46095
# Completed fit with Chi2: 92.0, p-val: 0.451 and the total amount of signal 153 +/- 51, background: 45476
# Completed fit with Chi2: 90.8, p-val: 0.485 and the total amount of signal 138 +/- 0, background: 44874
# Completed fit with Chi2: 89.6, p-val: 0.520 and the total amount of signal 144 +/- 0, background: 44251
# Completed fit with Chi2: 91.2, p-val: 0.475 and the total amount of signal 139 +/- 51, background: 43639
# Completed fit with Chi2: 90.1, p-val: 0.507 and the total amount of signal 142 +/- 2, background: 43020
# Completed fit with Chi2: 88.4, p-val: 0.559 and the total amount of signal 138 +/- 50, background: 42407
# Completed fit with Chi2: 92.2, p-val: 0.446 and the total amount of signal 139 +/- 3, background: 41790
# Completed fit with Chi2: 92.5, p-val: 0.437 and the total amount of signal 129 +/- 38, background: 41183
# Completed fit with Chi2: 95.8, p-val: 0.346 and the total amount of signal 129 +/- 0, background: 40566
# Completed fit with Chi2: 92.7, p-val: 0.431 and the total amount of signal 118 +/- 49, background: 39961
# Completed fit with Chi2: 99.8, p-val: 0.249 and the total amount of signal 121 +/- 50, background: 39342
# Completed fit with Chi2: 98.4, p-val: 0.280 and the total amount of signal 119 +/- 49, background: 38728
# Completed fit with Chi2: 96.9, p-val: 0.316 and the total amount of signal 117 +/- 47, background: 38112
# Completed fit with Chi2: 100.1, p-val: 0.240 and the total amount of signal 114 +/- 0, background: 37499
# Completed fit with Chi2: 97.8, p-val: 0.294 and the total amount of signal 113 +/- 6, background: 36883
# Completed fit with Chi2: 93.7, p-val: 0.401 and the total amount of signal 114 +/- 14, background: 36265
# Completed fit with Chi2: 95.7, p-val: 0.348 and the total amount of signal 115 +/- 45, background: 35648
# Completed fit with Chi2: 96.8, p-val: 0.319 and the total amount of signal 114 +/- 45, background: 35033
# Completed fit with Chi2: 95.4, p-val: 0.356 and the total amount of signal 113 +/- 44, background: 34417
# Completed fit with Chi2: 93.9, p-val: 0.397 and the total amount of signal 114 +/- 2, background: 33800
# Completed fit with Chi2: 95.1, p-val: 0.364 and the total amount of signal 107 +/- 47, background: 33189
# Completed fit with Chi2: 93.0, p-val: 0.422 and the total amount of signal 108 +/- 45, background: 32572
# Completed fit with Chi2: 94.0, p-val: 0.394 and the total amount of signal 107 +/- 0, background: 31956
# Completed fit with Chi2: 95.1, p-val: 0.364 and the total amount of signal 102 +/- 45, background: 31346
# Completed fit with Chi2: 94.9, p-val: 0.370 and the total amount of signal 99 +/- 0, background: 30731
# Completed fit with Chi2: 93.8, p-val: 0.398 and the total amount of signal 96 +/- 42, background: 30118
# Completed fit with Chi2: 98.5, p-val: 0.278 and the total amount of signal 94 +/- 42, background: 29503
# Completed fit with Chi2: 93.6, p-val: 0.405 and the total amount of signal 89 +/- 43, background: 28892
# Completed fit with Chi2: 96.8, p-val: 0.319 and the total amount of signal 81 +/- 39, background: 28284
# Completed fit with Chi2: 102.0, p-val: 0.201 and the total amount of signal 79 +/- 40, background: 27669
# Completed fit with Chi2: 103.5, p-val: 0.174 and the total amount of signal 76 +/- 27, background: 27054
# Completed fit with Chi2: 107.4, p-val: 0.116 and the total amount of signal 79 +/- 9, background: 26435
# Completed fit with Chi2: 112.0, p-val: 0.067 and the total amount of signal 70 +/- 38, background: 25827
# Completed fit with Chi2: 114.4, p-val: 0.049 and the total amount of signal 68 +/- 10, background: 25214
# Completed fit with Chi2: 116.6, p-val: 0.036 and the total amount of signal 69 +/- 38, background: 24596
# Completed fit with Chi2: 118.8, p-val: 0.027 and the total amount of signal 66 +/- 0, background: 23983
# Completed fit with Chi2: 112.7, p-val: 0.061 and the total amount of signal 67 +/- 1, background: 23365
# Completed fit with Chi2: 110.5, p-val: 0.081 and the total amount of signal 70 +/- 37, background: 22744
# Completed fit with Chi2: 105.6, p-val: 0.140 and the total amount of signal 70 +/- 36, background: 22129
# Completed fit with Chi2: 115.3, p-val: 0.044 and the total amount of signal 57 +/- 0, background: 21525
# Completed fit with Chi2: 111.4, p-val: 0.072 and the total amount of signal 46 +/- 33, background: 20920
# Completed fit with Chi2: 108.4, p-val: 0.104 and the total amount of signal 47 +/- 34, background: 20301
# Completed fit with Chi2: 110.9, p-val: 0.076 and the total amount of signal 43 +/- 31, background: 19689
# Completed fit with Chi2: 104.9, p-val: 0.151 and the total amount of signal 56 +/- 34, background: 19060
# Completed fit with Chi2: 105.2, p-val: 0.146 and the total amount of signal 55 +/- 34, background: 18444
# Completed fit with Chi2: 100.7, p-val: 0.228 and the total amount of signal 48 +/- 32, background: 17835
# Completed fit with Chi2: 102.0, p-val: 0.202 and the total amount of signal 51 +/- 32, background: 17215
# Completed fit with Chi2: 110.1, p-val: 0.084 and the total amount of signal 57 +/- 30, background: 16592
# Completed fit with Chi2: 102.9, p-val: 0.185 and the total amount of signal 50 +/- 30, background: 15982
# Completed fit with Chi2: 107.3, p-val: 0.117 and the total amount of signal 58 +/- 9, background: 15357
# Completed fit with Chi2: 103.3, p-val: 0.178 and the total amount of signal 48 +/- 28, background: 14752
# Completed fit with Chi2: 96.1, p-val: 0.336 and the total amount of signal 48 +/- 31, background: 14134
# Completed fit with Chi2: 100.7, p-val: 0.228 and the total amount of signal 61 +/- 30, background: 13504
# Completed fit with Chi2: 94.4, p-val: 0.384 and the total amount of signal 84 +/- 55, background: 12866
# Completed fit with Chi2: 96.6, p-val: 0.324 and the total amount of signal 89 +/- 55, background: 12243
# Completed fit with Chi2: 112.2, p-val: 0.065 and the total amount of signal 61 +/- 62, background: 11656
# Completed fit with Chi2: 113.0, p-val: 0.059 and the total amount of signal 48 +/- 65, background: 11052
# Completed fit with Chi2: 114.9, p-val: 0.046 and the total amount of signal 37 +/- 26, background: 10446
# Completed fit with Chi2: 103.6, p-val: 0.174 and the total amount of signal 48 +/- 51, background: 9818
# Completed fit with Chi2: 103.4, p-val: 0.176 and the total amount of signal 246 +/- 94, background: 9003
# Completed fit with Chi2: 101.1, p-val: 0.219 and the total amount of signal 403 +/- 97, background: 8231
# Completed fit with Chi2: 104.3, p-val: 0.161 and the total amount of signal 482 +/- 166, background: 7534
# Completed fit with Chi2: 109.6, p-val: 0.090 and the total amount of signal 173 +/- 222, background: 7228
# Completed fit with Chi2: 107.3, p-val: 0.117 and the total amount of signal 155 +/- 452, background: 6628
# Completed fit with Chi2: 110.3, p-val: 0.082 and the total amount of signal 494 +/- 108, background: 5673
# Completed fit with Chi2: 113.0, p-val: 0.059 and the total amount of signal 397 +/- 79, background: 5153
# Completed fit with Chi2: 109.1, p-val: 0.095 and the total amount of signal 117 +/- 145, background: 4817
# Completed fit with Chi2: 110.0, p-val: 0.085 and the total amount of signal 122 +/- 81, background: 4196
# Completed fit with Chi2: 103.4, p-val: 0.177 and the total amount of signal 327 +/- 108, background: 3374
# Completed fit with Chi2: 112.2, p-val: 0.065 and the total amount of signal 359 +/- 142, background: 2724
# Completed fit with Chi2: 100.0, p-val: 0.244 and the total amount of signal 293 +/- 66, background: 2175
# Completed fit with Chi2: 88.4, p-val: 0.558 and the total amount of signal 373 +/- 61, background: 1477
# Completed fit with Chi2: 90.2, p-val: 0.503 and the total amount of signal 129 +/- 89, background: 1106
# Completed fit with Chi2: 109.5, p-val: 0.080 and the total amount of signal 0 +/- 162, background: 617
# -0.04973857410524177

# %% [markdown]
# # Test with reweighting
